# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
population = pd.read_csv('population.csv').fillna('Not Given').replace('N.A.', 'Not Given')
population.insert(0, 'Index', [i+1 for i in range(population.shape[0])])
display(population)
# Out:
#      Index Country (or dependency)  Population (2020) Yearly Change  \
# 0        1                   China         1438207241         0.39%
# 1        2                   India         1377233523         0.99%
# 2        3           United States          330610570         0.59%
# 3        4               Indonesia          272931713         1.07%
# 4        5                Pakistan          219992900         2.00%
# ..     ...                     ...                ...           ...
# 230    231              Montserrat               4991         0.06%
# 231    232        Falkland Islands               3458         3.05%
# 232    233                    Niue               1624         0.68%
# 233    234                 Tokelau               1354         1.27%
# 234    235                Holy See                801         0.25%
#
#      Net Change  Density (P/Km²)  Land Area (Km²) Migrants (net) Fert. Rate  \
# 0       5540090              153          9388211      -348399.0        1.7
# 1      13586631              464          2973190      -532687.0        2.2
# 2       1937734               36          9147420       954806.0        1.8
# 3       2898047              151          1811570       -98955.0        2.3
# 4       4327022              287           770880      -233379.0        3.6
# ..          ...              ...              ...            ...        ...
# 230           3               50              100      Not Given  Not Given
# 231         103                0            12170      Not Given  Not Given
# 232          11                6              260      Not Given  Not Given
# 233          17              136               10      Not Given  Not Given
# 234           2             2003                0      Not Given  Not Given
#
#       Med. Age Urban Pop % World Share
# 0           38         61%      18.47%
# 1           28         35%      17.70%
# 2           38         83%       4.25%
# 3           30         56%       3.51%
# 4           23         35%       2.83%
# ..         ...         ...         ...
# 230  Not Given         10%       0.00%
# 231  Not Given         66%       0.00%
# 232  Not Given         46%       0.00%
# 233  Not Given          0%       0.00%
# 234  Not Given   Not Given       0.00%
#
# [235 rows x 12 columns]

# %%
# Population
fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(population['Country (or dependency)'][:20],
        population['Population (2020)'][:20], width=0.6, tick_label=population['Index'][:20])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Per Country',
             fontsize=24, color='#444444')
plt.title('The Most Populated 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population (People)', fontsize=18, color='#333333')

plt.show()

# %%
# Population
fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(population['Country (or dependency)'][-20:],
        population['Population (2020)'][-20:], width=0.6, tick_label=population['Index'][-20:])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Per Country',
             fontsize=24, color='#444444')
plt.title('The Least Ppopulated 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population (People)', fontsize=18, color='#333333')

plt.show()

# %%
# Population Change

def mod_percentage(p):
  p = str(p)
  p = p[:-1]
  return eval(p)

pop_rate_change = population.copy()
pop_rate_change['Yearly Change'] = [mod_percentage(
    i) for i in pop_rate_change['Yearly Change']]
pop_rate_change.sort_values(by=['Yearly Change'], inplace=True, ascending=False)
rate_plot = pd.concat([pop_rate_change[:20], pop_rate_change[-20:]], ignore_index=True)

fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(rate_plot['Country (or dependency)'],
        rate_plot['Yearly Change'], width=0.6, color="#009900", tick_label=rate_plot['Index'])
plt.bar(rate_plot['Country (or dependency)'][20:],
        rate_plot['Yearly Change'][20:], width=0.6, color="red")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Percentage Change Per Country',
             fontsize=24, color='#444444')
plt.title('The Highest and Lowest 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population Change (%)', fontsize=18, color='#333333')

plt.show()

# %%
# Population Change

pop_net_change = population.copy()
pop_net_change.sort_values(
    by=['Net Change'], inplace=True, ascending=False)
net_plot = pd.concat(
    [pop_net_change[:20], pop_net_change[-20:]], ignore_index=True)

fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(net_plot['Country (or dependency)'][:20],
        net_plot['Net Change'][:20], width=0.6, color="#009900", tick_label=net_plot['Index'][:20])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Net Change Per Country',
             fontsize=24, color='#444444')
plt.title('The Highest 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population Change (People)', fontsize=18, color='#333333')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(net_plot['Country (or dependency)'][-20:],
        net_plot['Net Change'][-20:], width=0.6, color="red", tick_label=net_plot['Index'][-20:])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Net Change Per Country',
             fontsize=24, color='#444444')
plt.title('The Lowest 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population Change (People)', fontsize=18, color='#333333')

plt.show()

# %%
# Population Density

pop_dense = population.copy()
pop_dense.sort_values(
    by=['Density (P/Km²)'], inplace=True, ascending=False)

fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(pop_dense['Country (or dependency)'][:20],
        pop_dense['Density (P/Km²)'][:20], width=0.6, tick_label=rate_plot['Index'][:20])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Density Per Country',
             fontsize=24, color='#444444')
plt.title('The Most Dense 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population Density (P/Km²)', fontsize=18, color='#333333')

plt.show()

# %%
# Population Density

pop_dense = population.copy()
pop_dense.sort_values(
    by=['Density (P/Km²)'], inplace=True, ascending=False)

fig, ax = plt.subplots(figsize=(16, 6))

plt.bar(pop_dense['Country (or dependency)'][-20:],
        pop_dense['Density (P/Km²)'][-20:], width=0.6, tick_label=rate_plot['Index'][-20:])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.margins(x=0)
plt.suptitle('Population Density Per Country',
             fontsize=24, color='#444444')
plt.title('The Least Dense 20', fontsize=18, color='#777777')
plt.xlabel('Country', fontsize=18, color='#333333')
plt.ylabel('Population Density (P/Km²)', fontsize=18, color='#333333')

plt.show()

# %%
# Migrants

migrants = population.copy()
display(migrants)
m = migrants[migrants['Migrants (net)'].str.contains('Not Given') == True]

display(m)
# Out:
#      Index   Country (or dependency)  Population (2020) Yearly Change  \
# 201    202               Isle of Man              84942         0.53%
# 202    203                   Andorra              77240         0.16%
# 203    204                  Dominica              71950         0.25%
# 204    205            Cayman Islands              65564         1.19%
# 205    206                   Bermuda              62323        -0.36%
# 206    207          Marshall Islands              59109         0.68%
# 207    208  Northern Mariana Islands              57490         0.60%
# 208    209                 Greenland              56750         0.17%
# 209    210            American Samoa              55215        -0.22%
# 210    211       Saint Kitts & Nevis              53123         0.71%
# 211    212            Faeroe Islands              48826         0.38%
# 212    213              Sint Maarten              42776         1.15%
# 213    214                    Monaco              39186         0.71%
# 214    215          Turks and Caicos              38609         1.38%
# 215    216              Saint Martin              38529         1.75%
# 216    217             Liechtenstein              38106         0.29%
# 217    218                San Marino              33917         0.21%
# 218    219                 Gibraltar              33693        -0.03%
# 219    220    British Virgin Islands              30190         0.67%
# 220    221     Caribbean Netherlands              26173         0.94%
# 221    222                     Palau              18077         0.48%
# 222    223              Cook Islands              17561         0.09%
# 223    224                  Anguilla              14976         0.90%
# 224    225                    Tuvalu              11762         1.25%
# 225    226           Wallis & Futuna              11276        -1.69%
# 226    227                     Nauru              10810         0.63%
# 227    228          Saint Barthelemy               9871         0.30%
# 228    229              Saint Helena               6073         0.30%
# 229    230   Saint Pierre & Miquelon               5800        -0.48%
# 230    231                Montserrat               4991         0.06%
# 231    232          Falkland Islands               3458         3.05%
# 232    233                      Niue               1624         0.68%
# 233    234                   Tokelau               1354         1.27%
# 234    235                  Holy See                801         0.25%
#
#      Net Change  Density (P/Km²)  Land Area (Km²) Migrants (net) Fert. Rate  \
# 201         449              149              570      Not Given  Not Given
# 202         123              164              470      Not Given  Not Given
# 203         178               96              750      Not Given  Not Given
# 204         774              274              240      Not Given  Not Given
# 205        -228             1246               50      Not Given  Not Given
# 206         399              329              180      Not Given  Not Given
# 207         343              125              460      Not Given  Not Given
# 208          98                0           410450      Not Given  Not Given
# 209        -121              276              200      Not Given  Not Given
# 210         376              205              260      Not Given  Not Given
# 211         185               35             1396      Not Given  Not Given
# 212         488             1261               34      Not Given  Not Given
# 213         278            26337                1      Not Given  Not Given
# 214         526               41              950      Not Given  Not Given
# 215         664              730               53      Not Given  Not Given
# 216         109              238              160      Not Given  Not Given
# 217          71              566               60      Not Given  Not Given
# 218         -10             3369               10      Not Given  Not Given
# 219         201              202              150      Not Given  Not Given
# 220         244               80              328      Not Given  Not Given
# 221          86               39              460      Not Given  Not Given
# 222          16               73              240      Not Given  Not Given
# 223         134              167               90      Not Given  Not Given
# 224         146              393               30      Not Given  Not Given
# 225        -193               80              140      Not Given  Not Given
# 226          68              541               20      Not Given  Not Given
# 227          30              470               21      Not Given  Not Given
# 228          18               16              390      Not Given  Not Given
# 229         -28               25              230      Not Given  Not Given
# 230           3               50              100      Not Given  Not Given
# 231         103                0            12170      Not Given  Not Given
# 232          11                6              260      Not Given  Not Given
# 233          17              136               10      Not Given  Not Given
# 234           2             2003                0      Not Given  Not Given
#
#       Med. Age Urban Pop % World Share
# 201  Not Given         53%       0.00%
# 202  Not Given         88%       0.00%
# 203  Not Given         74%       0.00%
# 204  Not Given         97%       0.00%
# 205  Not Given         97%       0.00%
# 206  Not Given         70%       0.00%
# 207  Not Given         88%       0.00%
# 208  Not Given         87%       0.00%
# 209  Not Given         88%       0.00%
# 210  Not Given         33%       0.00%
# 211  Not Given         43%       0.00%
# 212  Not Given         96%       0.00%
# 213  Not Given   Not Given       0.00%
# 214  Not Given         89%       0.00%
# 215  Not Given          0%       0.00%
# 216  Not Given         15%       0.00%
# 217  Not Given         97%       0.00%
# 218  Not Given   Not Given       0.00%
# 219  Not Given         52%       0.00%
# 220  Not Given         75%       0.00%
# 221  Not Given   Not Given       0.00%
# 222  Not Given         75%       0.00%
# 223  Not Given   Not Given       0.00%
# 224  Not Given         62%       0.00%
# 225  Not Given          0%       0.00%
# 226  Not Given   Not Given       0.00%
# 227  Not Given          0%       0.00%
# 228  Not Given         27%       0.00%
# 229  Not Given        100%       0.00%
# 230  Not Given         10%       0.00%
# 231  Not Given         66%       0.00%
# 232  Not Given         46%       0.00%
# 233  Not Given          0%       0.00%
# 234  Not Given   Not Given       0.00%
